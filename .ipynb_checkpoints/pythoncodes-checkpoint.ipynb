# %%
print("hello")
# Out:
# hello

# %%
a=9
b=20
sum= a+b
print("sum is ", sum)
# Out:
# sum is  29

# %%
print((not(2!=3) and True) or( False and True))
# Out:
# False

# %%
print(round(9.38263,4))
# Out:
# 9.3826

# %%
print(round(2.111864))
# Out:
# 2

# %%
print(divmod(47,3))
# Out:
# (15, 2)

# %%
isinstance(24,int)
# Out:
# True

# %%
isinstance(13.56,(int,float,str))
# Out:
# True

# %%
pow(2,4,3)
# Out:
# 1

# %%
 x = input("enter a string")
# Out:
# enter a string hi

# %%
print(x)
# Out:
# hi

# %%
 x = input("enter a integer")
# Out:
# enter a integer 9

# %%
print(x)
# Out:
# 9

# %%
type(x)
# Out:
# str

# %%
x= int(x)

# %%
type(x)
# Out:
# int

# %%
pow?
# Out:
# Signature: pow(base, exp, mod=None)
# Docstring:
# Equivalent to base**exp with 2 arguments or base**exp % mod with 3 arguments
#
# Some types, such as ints, are able to use a more efficient algorithm when
# invoked using the three argument form.
# Type:      builtin_function_or_method
